# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/kabhishm/top-american-colleges-2022
#
# Import the necessary libraries and create your dataframe(s).

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

college_data = pd.read_csv("top_colleges_2022.csv")

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
college_data.isnull().sum()
#The columns I really need are the student pop, and total grant aid. Of those columns only one has missing values, and it is only missing 3.
# Out:
# description                 0
# rank                        0
# organizationName            0
# state                       0
# studentPopulation           0
# campusSetting               0
# medianBaseSalary            7
# longitude                  40
# latitude                   40
# website                    21
# phoneNumber                70
# city                        0
# country                     0
# state.1                     0
# region                      9
# yearFounded                47
# stateCode                   9
# collegeType                 0
# carnegieClassification      0
# studentFacultyRatio         0
# totalStudentPop             0
# undergradPop                0
# totalGrantAid               3
# percentOfStudentsFinAid     3
# percentOfStudentsGrant      3
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
college_data.duplicated().any()
# Out:
# False

# %%
college_data.plot.bar(x='organizationName', y='totalGrantAid', figsize = (100, 5), rot=90)
# Out:
# <AxesSubplot:xlabel='organizationName'>

# %%
college_data.plot.bar(x='organizationName', y='studentPopulation', figsize = (100, 5), rot=90)
# Out:
# <AxesSubplot:xlabel='organizationName'>

# %%
#There are some outliers but I feel it is important to keep all data so that you can take note of the outliers to figure out why.
#I did not feel like there was any other irregular data in my csv file.

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
print(college_data[['studentPopulation', 'totalStudentPop']])
#With these two columns being exactly the same I did not feel like I needed to keep them both.
# Out:
#      studentPopulation  totalStudentPop
# 0                12195            12195
# 1                20961            20961
# 2                45878            45878
# 3                 8532             8532
# 4                33882            33882
# ..                 ...              ...
# 493               5901             5901
# 494               2961             2961
# 495               3163             3163
# 496               1980             1980
# 497              25128            25128
#
# [498 rows x 2 columns]

# %%
##I thought about it and realized that some of these columns are repeats and some are unnecessary.
college_data = college_data.drop(columns=['phoneNumber', 'website', 'totalStudentPop', 'longitude', 'latitude', 'stateCode'])
print(college_data.columns)
# Out:
# Index(['description', 'rank', 'organizationName', 'state', 'studentPopulation',
#        'campusSetting', 'medianBaseSalary', 'city', 'country', 'state.1',
#        'region', 'yearFounded', 'collegeType', 'carnegieClassification',
#        'studentFacultyRatio', 'undergradPop', 'totalGrantAid',
#        'percentOfStudentsFinAid', 'percentOfStudentsGrant'],
#       dtype='object')

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
#I feel like with the same as the irregular data there is not much that is inconsistant.
#The types of data given in each column is to be expected. There are no duplicates.
college_data.dtypes
# Out:
# description                 object
# rank                         int64
# organizationName            object
# state                       object
# studentPopulation            int64
# campusSetting               object
# medianBaseSalary           float64
# city                        object
# country                     object
# state.1                     object
# region                      object
# yearFounded                float64
# collegeType                 object
# carnegieClassification      object
# studentFacultyRatio          int64
# undergradPop                 int64
# totalGrantAid              float64
# percentOfStudentsFinAid    float64
# percentOfStudentsGrant     float64
# dtype: object

# %%
college_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   description              498 non-null    object
#  1   rank                     498 non-null    int64
#  2   organizationName         498 non-null    object
#  3   state                    498 non-null    object
#  4   studentPopulation        498 non-null    int64
#  5   campusSetting            498 non-null    object
#  6   medianBaseSalary         498 non-null    float64
#  7   city                     498 non-null    object
#  8   country                  498 non-null    object
#  9   state.1                  498 non-null    object
#  10  region                   489 non-null    object
#  11  yearFounded              498 non-null    float64
#  12  collegeType              498 non-null    object
#  13  carnegieClassification   498 non-null    object
# ...

# %%
college_data.isna().head(10)
# Out:
#    description   rank  organizationName  state  studentPopulation  \
# 0        False  False             False  False              False
# 1        False  False             False  False              False
# 2        False  False             False  False              False
# 3        False  False             False  False              False
# 4        False  False             False  False              False
# 5        False  False             False  False              False
# 6        False  False             False  False              False
# 7        False  False             False  False              False
# 8        False  False             False  False              False
# 9        False  False             False  False              False
#
#    campusSetting  medianBaseSalary   city  country  state.1  region  \
# 0          False             False  False    False    False   False
# 1          False             False  False    False    False   False
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# I did not, there were not missing values or duplicates in my dataset.
# 2. Did the process of cleaning your data give you new insights into your dataset?
# Yes, I was able to see some columns were repeats of others. I found out the datatype of each column, and I have only a handful of columns that have null values.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# That I need to narrow down the amounts of schools I want to monitor. It is a huge graph when you include all schools. as opposed to the top 5 and bottom 5. That may be a better way to focus the data.
